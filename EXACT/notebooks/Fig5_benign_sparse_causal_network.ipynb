# %% [markdown]
# # Fig. 5 — Benign sparse causal network (Setup A vs Setup B)
#
# This notebook is a minimal extraction of the Fig. 5 visualization logic from `EXACT-2-Copy1.ipynb`.
# It expects two edge CSVs with columns `u,v,strength[,domain_u,domain_v]`.

# %%
from pathlib import Path
from exact.fig5 import plot_benign_sparse_causal_network_two_panel

edges_a = Path('../results/sample_run/fig5_inputs/setupA_edges.csv')
edges_b = Path('../results/sample_run/fig5_inputs/setupB_edges.csv')
out_png = Path('../results/sample_run/figures/fig5_benign_sparse_causal_network.png')

plot_benign_sparse_causal_network_two_panel(
    edges_csv_A=edges_a,
    edges_csv_B=edges_b,
    out_png=out_png,
    title_A='Setup A',
    title_B='Setup B',
)
print('Saved:', out_png)
